# %% [markdown]
# # LEO PRATAMA
# # 1915016169

# %%
import pandas as pd #Manipulasi dan analisis data
from matplotlib import pyplot as plt

data = pd.read_csv("vgsales.csv")

data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data['Platform'].value_counts() #Menampilkan Nilai Data Platform
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# ## Diagram Batang

# %%
x = list(data.iloc[:,6])
y = list(data.iloc[:,10])

plt.bar(x, y, color='red') #Jumlah Sales NA dan Sales Global
plt.title("Jumlah Sales")
plt.xlabel("NA_Sales")
plt.ylabel("Global_Sales")
# Out:
# Text(0, 0.5, 'Global_Sales')

# %% [markdown]
# ## Diagram Garis atau Grafik Plot dan garis

# %%
data.head()
plt.plot(data.Year, data.Global_Sales)
plt.title("Penjualan tahunan")
plt.xlabel("Tahun")
plt.ylabel("Penjualan Global")

#Visual Data Global Sales Setiap Tahun
# Out:
# Text(0, 0.5, 'Penjualan Global')

# %% [markdown]
# ## Diagram Pie

# %%
labels = data['Genre'].value_counts().rename_axis('Game').reset_index(name='Penjualan')
labels = pd.DataFrame(labels)
labels.head(10)
# Out:
#            Game  Penjualan
# 0        Action       3316
# 1        Sports       2346
# 2          Misc       1739
# 3  Role-Playing       1488
# 4       Shooter       1310
# 5     Adventure       1286
# 6        Racing       1249
# 7      Platform        886
# 8    Simulation        867
# 9      Fighting        848

# %%
plt.figure(figsize=(10,10))
plt.pie(data['Genre'].value_counts(), labels=labels['Game'], autopct='%.1f%%', startangle=90)

plt.title('Penjualan Global')
plt.show() #PIE Chart GLobal Sales

# %% [markdown]
# # Kesimpulan
# ### Kesimpulan dari Visualisai data adalah disini kita menunjukan data kita yang telah di visualisasikan menggunakan diagram yang telah kita tentukan dengan melihat hasil atau informasi dari data tersebut, fungsi lain dari data visualisasi data ini adalah agar memudahkan orang awam dapat melihat hasil atau informasi dari data yang kita analisis

# %% [markdown]
# ##### @Copyright LEO169
